# %%
import models

# %%
models.compare_mc_to_sim_states(
    num_classes=2,
    num_servers=1,
    arrival_rates=[5, 6],
    service_rates=[12, 13],
    thetas=[[None, 3], [1, None]],
    bound=40,
    max_simulation_time=20000,
    warmup=200,
    max_state=50,
);
# Out:
# 100%|██████████| 20000.0/20000 [00:13<00:00, 1447.20it/s]

# %%
models.compare_mc_to_sim_states(
    num_classes=2,
    num_servers=1,
    arrival_rates=[3, 6],
    service_rates=[12, 13],
    thetas=[[None, 2], [5, None]],
    bound=40,
    max_simulation_time=20000,
    warmup=200,
    max_state=50,
);
# Out:
# 100%|██████████| 20000.0/20000 [00:10<00:00, 1979.23it/s]

# %%
models.compare_mc_to_sim_states(
    num_classes=3,
    num_servers=1,
    arrival_rates=[2, 3, 2],
    service_rates=[9, 8, 8],
    thetas=[[None, 2, 1], [1, None, 1], [1, 2, None]],
    bound=20,
    max_simulation_time=20000,
    warmup=200,
    max_state=50,
);
# Out:
# 100%|██████████| 20000.0/20000 [00:13<00:00, 1470.89it/s]

# %%
models.compare_mc_to_sim_states(
    num_classes=2,
    num_servers=2,
    arrival_rates=[5, 6],
    service_rates=[6.5, 7.5],
    thetas=[[None, 2], [4, None]],
    bound=40,
    max_simulation_time=50000,
    warmup=200,
    max_state=50,
);
# Out:
# 100%|██████████| 50000.0/50000 [00:37<00:00, 1343.27it/s]

# %%
models.compare_mc_to_sim_states(
    num_classes=2,
    num_servers=3,
    arrival_rates=[5, 6],
    service_rates=[3.8, 4],
    thetas=[[None, 1], [2, None]],
    bound=55,
    max_simulation_time=80000,
    warmup=200,
    max_state=110,
);
# Out:
# 100%|██████████| 80000.0/80000 [01:46<00:00, 748.20it/s]

# %%
models.compare_mc_to_sim_states(
    num_classes=3,
    num_servers=2,
    arrival_rates=[1, 3, 1.5],
    service_rates=[3, 2.5, 2],
    thetas=[[None, 1, 1], [1.5, None, 1], [1, 1, None]],
    bound=20,
    max_simulation_time=80000,
    warmup=200,
    max_state=110,
);
# Out:
# 100%|██████████| 80000.0/80000 [00:58<00:00, 1359.74it/s]
