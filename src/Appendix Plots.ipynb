# %%
import models

# %%
fig = models.compare_mc_to_sim_states(
    num_classes=2,
    num_servers=2,
    arrival_rates=[3, 4],
    service_rates=[4, 5],
    thetas=[[None, 7], [12, None]],
    bound=24,
    max_simulation_time=200000,
    warmup=5000,
    cooldown_time=5000,
    max_state=24,
    progress_bar=True,
)
fig.savefig("../tex/img/appendix_2class.pdf")
# Out:
# 100%|██████████████████████████████| 200000.0/200000 [05:55<00:00, 563.03it/s]

# %%
fig = models.compare_mc_to_sim_states(
    num_classes=3,
    num_servers=2,
    arrival_rates=[2, 1, 4],
    service_rates=[4, 4.5, 5],
    thetas=[[None, 2, 4], [1, None, 5], [1, 3, None]],
    bound=18,
    max_simulation_time=200000,
    warmup=5000,
    cooldown_time=5000,
    max_state=18,
    progress_bar=True,
)
fig.savefig("../tex/img/appendix_3class.pdf")
# Out:
# 100%|██████████████████████████████| 200000.0/200000 [04:12<00:00, 793.57it/s]

# %%
fig = models.compare_mc_to_sim_states(
    num_classes=4,
    num_servers=2,
    arrival_rates=[0.5, 1.5, 1, 3],
    service_rates=[3.5, 4, 3.5, 5],
    thetas=[[None, 2, 4, 1], [1, None, 5, 1], [1, 3, None, 3], [2, 1, 1, None]],
    bound=10,
    max_simulation_time=200000,
    warmup=5000,
    cooldown_time=5000,
    max_state=10,
    progress_bar=True,
)
fig.savefig("../tex/img/appendix_4class.pdf")
# Out:
# 100%|██████████████████████████████| 200000.0/200000 [03:57<00:00, 843.74it/s]
